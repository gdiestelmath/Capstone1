# %%
ls
# Out:
# Census_2000_Data_Cleanedup.xls  Demo2000B.csv
# Census_2010_Data_Cleanedup.xls  Demo2010A.csv
# Crime.csv                       Demo2010B.csv
# Demo2000A.csv                   Untitled.ipynb

# %%
#Imports
import pandas as pd

dfcrime=pd.read_csv('Crime.csv')
df2000A=pd.read_csv('Demo2000A.csv')
df2000B=pd.read_csv('Demo2000B.csv')
df2010A=pd.read_csv('Demo2010A.csv')
df2010B=pd.read_csv('Demo2010B.csv')

# %%
dfcrime.head(1)
# Out:
#                                              Address Case Number  \
# 0  12500 BLOCK OF SE STARK ST                    ...   16-162605
#
#   Crime Against Neighborhood  Number of Records Occur Date Occur Month Year  \
# 0      Property    Mill Park                  1    5/23/16           5/1/16
#
#    Occur Time     Offense Category  Offense Count         Offense Type  \
# 0         539  Motor Vehicle Theft              1  Motor Vehicle Theft
#
#    Open Data Lat  Open Data Lon  Open Data X  Open Data Y Report Date  \
# 0      45.519002    -122.534269    7680741.0     681878.0     5/23/16
#
#   Report Month Year
# 0            May-16

# %%
df2000A.head(7)
# Out:
#                  Unnamed: 0 Total Population  \
# 0                       NaN              NaN
# 1                       NaN              NaN
# 2                       NaN              NaN
# 3                       NaN            Total
# 4  NEIGHBORHOOD ASSOCIATION         P0010001
# 5                   ALAMEDA             5214
# 6               ARBOR LODGE             6153
#
#                           Unnamed: 2                       Unnamed: 3  \
# 0  Hispanic or latino origin by race                              NaN
# 1             Not Hispanic or Latino                              NaN
# 2                                NaN                              NaN
# 3                        White alone  Black or African American alone
# 4                           P0050003                         P0050004
# 5                               4617                              112
# 6                               4702                              299
#
# ...

# %%
df=df2000A.iloc[4:,:]
df2000A=df

# %%
df2000A.reset_index()
df2000A.head()
# Out:
#                  Unnamed: 0 Total Population Unnamed: 2 Unnamed: 3 Unnamed: 4  \
# 4  NEIGHBORHOOD ASSOCIATION         P0010001   P0050003   P0050004   P0050005
# 5                   ALAMEDA             5214       4617        112          9
# 6               ARBOR LODGE             6153       4702        299         44
# 7   ARDENWALD-JOHNSON CREEK             4748       4105         87         35
# 8                     ARGAY             6006       3201        751         57
#
#   Unnamed: 5 Unnamed: 6 Unnamed: 7 Unnamed: 8 Unnamed: 9     ...       \
# 4   P0050006   P0050007   P0050008   P0050009   P0050011     ...
# 5        125         10         15        152        105     ...
# 6        306         67         33        278        177     ...
# 7         83         10          9        148        139     ...
# 8        616        109         15        221        299     ...
#
#   Unnamed: 91 Unnamed: 92 Unnamed: 93 Unnamed: 94 Unnamed: 95 Unnamed: 96  \
# ...
