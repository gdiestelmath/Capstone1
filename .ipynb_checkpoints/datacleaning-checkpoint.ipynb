# %%
# Remove extraneous rows and unimportant columns from all dataframes and write to new files.
# Need to get neighborhood demograhics for 2015 or 2016. Not enough crime data for 2010

# %%
#Imports
import pandas as pd

#Get data
dfcrime=pd.read_csv('./CrimeData/Crime.csv')
df2000A=pd.read_csv('./CrimeData/Demo2000A.csv')
df2000B=pd.read_csv('./CrimeData/Demo2000B.csv')
df2010A=pd.read_csv('./CrimeData/Demo2010A.csv')
df2010B=pd.read_csv('./CrimeData/Demo2010B.csv')

# %%
dfcrime.head(10)
# Out:
#                                              Address  Case Number  \
# 0  12500 BLOCK OF SE STARK ST                    ...    16-162605
# 1                         NW 14TH AVE / NW GLISAN ST    16-905957
# 2  2500 BLOCK OF NW VAUGHN ST                    ...    16-905924
# 3  400 BLOCK OF NE EMERSON ST                    ...    16-159874
# 4  17000 BLOCK OF SE MORRISON CT                 ...    16-162123
# 5                                                NaN  16-X4581646
# 6                                                NaN  16-X4581646
# 7  4700 BLOCK OF SE ANDEREGG LOOP                ...    16-905930
# 8  6200 BLOCK OF SE RAMONA ST                    ...    16-906042
# 9  6000 BLOCK OF NE DAVIS ST                     ...    16-165061
#
#   Crime Against     Neighborhood  Number of Records Occur Date  \
# 0      Property        Mill Park                  1    5/23/16
# 1      Property            Pearl                  1    5/20/16
# ...

# %%
Dates=dfcrime['Occur Date']
Dates2010=[x for x in Dates if x.endswith('/15')]
len(Dates2010)
# Out:
# 38722

# %%
df2000A.head(10)
# Out:
#                  Unnamed: 0 Total Population  \
# 0                       NaN              NaN
# 1                       NaN              NaN
# 2                       NaN              NaN
# 3                       NaN            Total
# 4  NEIGHBORHOOD ASSOCIATION         P0010001
# 5                   ALAMEDA             5214
# 6               ARBOR LODGE             6153
# 7   ARDENWALD-JOHNSON CREEK             4748
# 8                     ARGAY             6006
# 9         ARLINGTON HEIGHTS              718
#
#                           Unnamed: 2                       Unnamed: 3  \
# 0  Hispanic or latino origin by race                              NaN
# 1             Not Hispanic or Latino                              NaN
# 2                                NaN                              NaN
# 3                        White alone  Black or African American alone
# 4                           P0050003                         P0050004
# ...

# %%
df2000B.head(10)
# Out:
#                  Unnamed: 0 Total Population  \
# 0                       NaN              NaN
# 1                       NaN              NaN
# 2                       NaN              NaN
# 3                       NaN            Total
# 4  NEIGHBORHOOD ASSOCIATION          P001001
# 5                   ALAMEDA             5037
# 6               ARBOR LODGE             6065
# 7   ARDENWALD-JOHNSON CREEK             4756
# 8                     ARGAY             5818
# 9         ARLINGTON HEIGHTS              694
#
#                           Unnamed: 2                       Unnamed: 3  \
# 0  Hispanic or latino origin by race                              NaN
# 1             Not Hispanic or Latino                              NaN
# 2                                NaN                              NaN
# 3                        White alone  Black or African American alone
# 4                            P008003                          P008004
# ...

# %%
df2010A.head(10)
# Out:
#                  Unnamed: 0 Total Population  \
# 0                       NaN              NaN
# 1                       NaN              NaN
# 2                       NaN              NaN
# 3                       NaN            Total
# 4  NEIGHBORHOOD ASSOCIATION         P0010001
# 5                   ALAMEDA             5214
# 6               ARBOR LODGE             6153
# 7   ARDENWALD-JOHNSON CREEK             4748
# 8                     ARGAY             6006
# 9         ARLINGTON HEIGHTS              718
#
#                           Unnamed: 2                       Unnamed: 3  \
# 0  Hispanic or latino origin by race                              NaN
# 1             Not Hispanic or Latino                              NaN
# 2                                NaN                              NaN
# 3                        White alone  Black or African American alone
# 4                           P0050003                         P0050004
# ...

# %%
df2010B.head(10)
# Out:
#                        Unnamed: 0 Total Population  \
# 0                             NaN              NaN
# 1                             NaN              NaN
# 2                             NaN              NaN
# 3                             NaN            Total
# 4            NEIGHBORHOOD OR PART         P0010001
# 5                  ALAMEDA (PART)             4200
# 6       ALAMEDA/BEAUMONT-WILSHIRE              161
# 7               ALAMEDA/IRVINGTON              853
# 8                     ARBOR LODGE             6153
# 9  ARDENWALD-JOHNSON CREEK (PART)             4480
#
#                           Unnamed: 2                       Unnamed: 3  \
# 0  Hispanic or latino origin by race                              NaN
# 1             Not Hispanic or Latino                              NaN
# 2                                NaN                              NaN
# 3                        White alone  Black or African American alone
# ...
